# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Simple APIs
# ## Random User and Fruitvice API Examples
#
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Security**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2023-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2023-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py): started
#   Building wheel for randomuser (setup.py): finished with status 'done'
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5083 sha256=3e1034086acea0fea3994b37eeca14b34b5e1435461b35015075615077d2fd64
#   Stored in directory: c:\users\win\appdata\local\pip\cache\wheels\41\6f\23\878c103a235dc2d4e85a3965c124aae8a28470c541b81aa2ba
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ertifi (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ertifi (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x24db37b2d60>,
#  <randomuser.RandomUser at 0x24db37b2bb0>,
#  <randomuser.RandomUser at 0x24db37b2ee0>,
#  <randomuser.RandomUser at 0x24db37b2c40>,
#  <randomuser.RandomUser at 0x24db37b2ac0>,
#  <randomuser.RandomUser at 0x24db37b2e50>,
#  <randomuser.RandomUser at 0x24db37b2cd0>,
#  <randomuser.RandomUser at 0x24db37b2370>,
#  <randomuser.RandomUser at 0x24db37b2790>,
#  <randomuser.RandomUser at 0x24db379f8e0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %%
name
# Out:
# 'Barış Kocabıyık'

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Darrell Henderson   darrell.henderson@example.com
# Ronja Pulkkinen   ronja.pulkkinen@example.com
# Kelly Smith   kelly.smith@example.com
# Annabelle Walker   annabelle.walker@example.com
# Sylvia Damm   sylvia.damm@example.com
# محیا کوتی   mhy.khwty@example.com
# Scarlett Watkins   scarlett.watkins@example.com
# Catalina Duran   catalina.duran@example.com
# Çetin Çetiner   cetin.cetiner@example.com
# Ayla Ødegård   ayla.odegard@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/62.jpg
# https://randomuser.me/api/portraits/women/7.jpg
# https://randomuser.me/api/portraits/men/23.jpg
# https://randomuser.me/api/portraits/women/58.jpg
# https://randomuser.me/api/portraits/women/63.jpg
# https://randomuser.me/api/portraits/women/54.jpg
# https://randomuser.me/api/portraits/women/5.jpg
# https://randomuser.me/api/portraits/women/82.jpg
# https://randomuser.me/api/portraits/men/93.jpg
# https://randomuser.me/api/portraits/women/52.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                     Name  Gender             City           State  \
# 0           Gilbert Joly    male  Laufen-Uhwiesen          Genève
# 1         Christa Masson  female         Rothrist         Thurgau
# 2           هلیا نكو نظر  female            قزوین    خراسان شمالی
# 3           Pippa Hughes  female       Upper Hutt          Nelson
# 4          Isaí da Rocha    male       Maranguape  Rio de Janeiro
# 5                Jack Li    male     New Plymouth        Auckland
# 6  Klaas Van Capelleveen    male       Maria Hoop      Overijssel
# 7           Kaya Çağıran    male        Zonguldak         Bilecik
# 8         Vedat Kaplangı    male          Aksaray      Kırklareli
# 9              عباس گلشن    male            سنندج    خراسان شمالی
#
#                               Email                       DOB  \
# 0          gilbert.joly@example.com  1998-06-15T16:05:18.686Z
# 1        christa.masson@example.com  1974-12-22T10:15:05.009Z
# 2            hly.nkwnzr@example.com  1990-09-05T21:06:37.263Z
# 3          pippa.hughes@example.com  1989-12-24T17:28:55.778Z
# 4          isai.darocha@example.com  1981-04-25T06:13:22.805Z
# 5               jack.li@example.com  1958-10-08T11:45:33.563Z
# 6  klaas.vancapelleveen@example.com  1990-07-01T01:30:58.581Z
# 7          kaya.cagiran@example.com  1954-03-31T10:55:08.099Z
# 8        vedat.kaplangi@example.com  1957-11-03T08:16:27.084Z
# 9            aabs.glshn@example.com  1979-08-10T16:28:16.406Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/67.jpg
# 1  https://randomuser.me/api/portraits/women/11.jpg
# 2  https://randomuser.me/api/portraits/women/51.jpg
# 3  https://randomuser.me/api/portraits/women/93.jpg
# 4    https://randomuser.me/api/portraits/men/23.jpg
# 5    https://randomuser.me/api/portraits/men/66.jpg
# 6    https://randomuser.me/api/portraits/men/18.jpg
# 7    https://randomuser.me/api/portraits/men/27.jpg
# 8    https://randomuser.me/api/portraits/men/63.jpg
# 9    https://randomuser.me/api/portraits/men/74.jpg

# %%
df1 = pd.DataFrame(get_users())

# %%
df1
# Out:
#               Name  Gender                City               State  \
# 0  Anthony Ouellet    male           Greenwood             Alberta
# 1    Archie Wright    male           Whangarei         Marlborough
# 2      Pippa Singh  female            Auckland            Gisborne
# 3      Isaac Denis    male               Nancy             Gironde
# 4   Tiago Leclercq    male                 Pau               Yonne
# 5   Scott Chambers    male               Tweed     New South Wales
# 6  Kenneth Ommedal    male                Åros            Vestfold
# 7      Lucas Sirko    male            Carleton        Saskatchewan
# 8     Laica Aragão  female  Ribeirão das Neves  Mato Grosso do Sul
# 9  Stephen Garrett    male             Leixlip             Wicklow
#
#                          Email                       DOB  \
# 0  anthony.ouellet@example.com  1967-02-23T17:50:04.849Z
# 1    archie.wright@example.com  1988-10-07T12:05:01.721Z
# 2      pippa.singh@example.com  1948-09-05T03:14:50.045Z
# 3      isaac.denis@example.com  1990-11-03T22:06:15.447Z
# 4   tiago.leclercq@example.com  1996-02-27T08:07:55.342Z
# 5   scott.chambers@example.com  1961-02-23T11:52:58.863Z
# 6  kenneth.ommedal@example.com  1976-06-20T06:38:04.828Z
# 7      lucas.sirko@example.com  1983-03-06T12:31:20.929Z
# 8     laica.aragao@example.com  1964-11-17T19:02:26.207Z
# 9  stephen.garrett@example.com  1944-09-26T16:39:49.333Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/76.jpg
# 1    https://randomuser.me/api/portraits/men/84.jpg
# 2  https://randomuser.me/api/portraits/women/12.jpg
# 3    https://randomuser.me/api/portraits/men/78.jpg
# 4    https://randomuser.me/api/portraits/men/73.jpg
# 5    https://randomuser.me/api/portraits/men/45.jpg
# 6    https://randomuser.me/api/portraits/men/18.jpg
# 7    https://randomuser.me/api/portraits/men/85.jpg
# 8  https://randomuser.me/api/portraits/women/26.jpg
# 9    https://randomuser.me/api/portraits/men/35.jpg

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2023-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
# 40     Jackfruit  94         Moraceae           Rosales    Artocarpus
# 41  Horned Melon  95    Cucurbitaceae      Cucurbitales       Cucumis
# 42      Hazelnut  96       Betulaceae           Fagales       Corylus
# 43        Pomelo  98         Rutaceae        Sapindales        Citrus
# 44    Mangosteen  99       Clusiaceae      Malpighiales      Garcinia
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 43, 'fat': 0.4, 'sugar': 1.0, 'ca...
# 26  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 27  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 28  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 29  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 30  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 31  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 32  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 33  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 34  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 36  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 37  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 38  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 39  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 40  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 41  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...
# 42  {'calories': 628, 'fat': 61.0, 'sugar': 4.3, '...
# 43  {'calories': 37, 'fat': 0.0, 'sugar': 8.5, 'ca...
# 44  {'calories': 73, 'fat': 0.58, 'sugar': 16.11, ...

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
# 40     Jackfruit  94         Moraceae           Rosales    Artocarpus
# 41  Horned Melon  95    Cucurbitaceae      Cucurbitales       Cucumis
# 42      Hazelnut  96       Betulaceae           Fagales       Corylus
# 43        Pomelo  98         Rutaceae        Sapindales        Citrus
# 44    Mangosteen  99       Clusiaceae      Malpighiales      Garcinia
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   43            0.40              1.00
# 26                   34            0.00              8.00
# 27                   45            0.40              9.10
# 28                   36            0.40              3.00
# 29                   25            0.10              1.70
# 30                   83            1.20             13.70
# 31                   60            1.50              8.00
# 32                   69            0.16             16.00
# 33                   43            0.39              8.10
# 34                   44            0.40              3.00
# 35                  160           14.66              0.66
# 36                   61            0.50              8.90
# 37                   46            0.10              4.00
# 38                   50            0.30              8.00
# 39                   39            0.25              8.40
# 40                   95            0.00             19.10
# 41                   44            1.26              0.50
# 42                  628           61.00              4.30
# 43                   37            0.00              8.50
# 44                   73            0.58             16.11
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                     11.00                0.00
# 26                      8.00                0.00
# 27                      8.30                0.00
# 28                      7.00                1.00
# 29                      8.40                0.30
# 30                     18.70                1.70
# 31                      9.00                9.00
# 32                     18.10                0.72
# 33                      9.80                1.44
# 34                      8.00                0.60
# 35                      8.53                2.00
# 36                     14.60                1.14
# 37                     12.20                0.40
# 38                     12.00                1.00
# 39                      9.50                0.90
# 40                     23.20                1.72
# 41                      7.56                1.78
# 42                     17.00               15.00
# 43                      9.67                0.82
# 44                     17.91                0.41

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
cal_banana = df2.loc[df2["name"] == 'Banana']
cal_banana.iloc[0]['nutritions.calories']
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
# 1. Using `requests.get("url")` function, load your data.

# %%
# Write your code here
data2 = requests.get("https://cat-fact.herokuapp.com/facts")

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://cat-fact.herokuapp.com/facts")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here
results2 = json.loads(data2.text)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame.

# %%
# Write your code here
df3 = pd.DataFrame(results2)

df3
# Out:
#                                               status  \
# 0                 {'verified': True, 'sentCount': 1}
# 1  {'verified': True, 'feedback': '', 'sentCount'...
# 2                 {'verified': True, 'sentCount': 1}
# 3                 {'verified': True, 'sentCount': 1}
# 4                 {'verified': True, 'sentCount': 1}
#
#                         _id                      user  \
# 0  58e00b5f0aac31001185ed24  58e007480aac31001185ecef
# 1  5887e1d85c873e0011036889  5a9ac18c7478810ea6c06381
# 2  58e008780aac31001185ed05  58e007480aac31001185ecef
# 3  58e009390aac31001185ed10  58e007480aac31001185ecef
# 4  58e00af60aac31001185ed1d  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  When asked if her husband had any hobbies, Mar...    0   user
# 1  Cats make about 100 different sounds. Dogs mak...    0   user
# 2  Owning a cat can reduce the risk of stroke and...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  It was illegal to slay cats in ancient Egypt, ...    0   user
#
#                   updatedAt type                 createdAt  deleted   used
# 0  2020-08-23T20:20:01.611Z  cat  2018-02-19T21:20:03.434Z    False  False
# 1  2020-09-03T16:39:39.578Z  cat  2018-01-15T21:20:00.003Z    False   True
# 2  2020-08-23T20:20:01.611Z  cat  2018-03-29T20:20:03.844Z    False  False
# 3  2020-08-23T20:20:01.611Z  cat  2018-03-04T21:20:02.979Z    False  False
# 4  2020-09-16T20:20:04.164Z  cat  2018-01-15T21:20:02.945Z    False   True

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3.drop(columns="status",inplace=True)
# df3
# ```
#
# </details>

# %%
df3.drop(columns="status",inplace=True)
df3
# Out:
#                         _id                      user  \
# 0  58e00b5f0aac31001185ed24  58e007480aac31001185ecef
# 1  5887e1d85c873e0011036889  5a9ac18c7478810ea6c06381
# 2  58e008780aac31001185ed05  58e007480aac31001185ecef
# 3  58e009390aac31001185ed10  58e007480aac31001185ecef
# 4  58e00af60aac31001185ed1d  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  When asked if her husband had any hobbies, Mar...    0   user
# 1  Cats make about 100 different sounds. Dogs mak...    0   user
# 2  Owning a cat can reduce the risk of stroke and...    0   user
# 3  Most cats are lactose intolerant, and milk can...    0   user
# 4  It was illegal to slay cats in ancient Egypt, ...    0   user
#
#                   updatedAt type                 createdAt  deleted   used
# 0  2020-08-23T20:20:01.611Z  cat  2018-02-19T21:20:03.434Z    False  False
# 1  2020-09-03T16:39:39.578Z  cat  2018-01-15T21:20:00.003Z    False   True
# 2  2020-08-23T20:20:01.611Z  cat  2018-03-29T20:20:03.844Z    False  False
# 3  2020-08-23T20:20:01.611Z  cat  2018-03-04T21:20:02.979Z    False  False
# 4  2020-09-16T20:20:04.164Z  cat  2018-01-15T21:20:02.945Z    False   True

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# [Svitlana Kramar](www.linkedin.com/in/svitlana-kramar)
#
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
#                                 Copyright © 2020 IBM Corporation. All rights reserved.
